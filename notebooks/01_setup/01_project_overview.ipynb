# %%
# 01_project_overview - Vattenfall Lakehouse Capstone

# ---------------------------------------
# 1. Project Introduction
# ---------------------------------------

print("Vattenfall Week 9 Capstone Project")
print("Energy Operations and Market Intelligence Lakehouse")

# ---------------------------------------
# 2. Data Sources
# ---------------------------------------

data_sources = [
    "Energy Market Prices",
    "Weather Data",
    "Grid Telemetry Events",
    "Reference Data"
]

print("\nData Sources:")
for source in data_sources:
    print(f"- {source}")

# ---------------------------------------
# 3. Architecture Overview (High Level)
# ---------------------------------------

architecture_flow = [
    "Raw Data Sources",
    "Landing Zone",
    "Bronze Layer (Ingestion)",
    "Silver Layer (Transformation)",
    "Gold Layer (Analytics)"
]

print("\nData Flow:")
for step in architecture_flow:
    print(f"→ {step}")

# ---------------------------------------
# 4. Technology Stack (Conceptual)
# ---------------------------------------

stack = [
    "Databricks Lakehouse",
    "Unity Catalog",
    "Python Modular Code",
    "Notebook Orchestration",
    "Config Driven Design"
]

print("\nTechnology Stack:")
for tech in stack:
    print(f"- {tech}")

# ---------------------------------------
# 5. Day 1 Focus
# ---------------------------------------

focus = [
    "Repository structure setup",
    "Configuration design",
    "Unity Catalog governance setup",
    "Bronze ingestion planning",
    "Notebook orchestration design"
]

print("\nDay 1 Focus:")
for item in focus:
    print(f"- {item}")

# ---------------------------------------
# 6. Summary
# ---------------------------------------

print("\nProject initialized successfully. Ready for Bronze layer implementation.")
